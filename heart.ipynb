# %% [markdown]
# <a href="https://colab.research.google.com/github/karishmasd/Heart-Attack-Risk-Predictor/blob/main/heart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Import Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df= pd.read_csv("/content/drive/MyDrive/Resume/Resume/Project no 1/heart.csv")

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df= df.drop(['oldpeak','slp','thall'],axis=1)

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  caa  output
# 0   63    1   3     145   233    1        0       150     0    0       1
# 1   37    1   2     130   250    0        1       187     0    0       1
# 2   41    0   1     130   204    0        0       172     0    0       1
# 3   56    1   1     120   236    0        1       178     0    0       1
# 4   57    0   0     120   354    0        1       163     1    0       1

# %% [markdown]
# **Data Analytics**

# %% [markdown]
# Age : Age of the patient
#
#
# Sex : Sex of the patient
#
#
# exang: exercise induced angina (1 = yes; 0 = no)
#
#
#
# ca: number of major vessels (0-3)
#
#
# cp : Chest Pain type chest pain type
#
#
#       Value 0: typical angina
#       Value 1: atypical angina
#       Value 2: non-anginal pain
#       Value 3: asymptomatic
#
#
# trtbps : resting blood pressure (in mm Hg)
#
#
# chol : cholestoral in mg/dl fetched via BMI sensor
#
#
# fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#
#
# rest_ecg : resting electrocardiographic results
#
#
#     Value 0: normal
#     Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#     Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
#
#
# thalach : maximum heart rate achieved
#
#
# target : 0= less chance of heart attack 1= more chance of heart attack

# %%
df.shape
# Out:
# (303, 11)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# caa         0
# output      0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset

# %%
df.corr()
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exng      0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# caa       0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# output   -0.225439 -0.280937  0.433798 -0.144931 -0.085239 -0.028046
#
#            restecg  thalachh      exng       caa    output
# age      -0.116211 -0.398522  0.096801  0.276326 -0.225439
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# It is clear that our Variables are not highly correlated

# %% [markdown]
# **Uni and Bi Variate Analysis on Features**
#
#
# to understand its distribution, central tendency (mean, median, mode), and spread (variance, standard deviation).
#
#
# Common Tool: For numerical features:
#
# Histograms
#
# Box plots
#
# Descriptive statistics (mean, median, mode, std dev)
#
# For categorical features:
#
# Bar charts
#
# Value counts

# %%
plt.figure(figsize=(15, 7))
plt.title("Age of Patients")
plt.xlabel("Age")
sns.countplot(x='age',data=df)
# Out:
# <Axes: title={'center': 'Age of Patients'}, xlabel='Age', ylabel='count'>

# %% [markdown]
# Observation: Paitents from 51 to 67 are in the majority

# %%
plt.figure(figsize=(3, 6))
plt.title("Sex of Patients,0=Female and 1=Male")
sns.countplot(x='sex',data=df)
sex_counts = df['sex'].value_counts()
ratio = sex_counts[1] / sex_counts[0]
print(f"Male to Female Ratio: {ratio:.2f}")
# Out:
# Male to Female Ratio: 2.16

# %%
cp_data = df['cp'].value_counts().reset_index()

cp_data.columns = ['cp_type', 'count']

cp_data['cp_type'] = cp_data['cp_type'].astype(str)

cp_data.loc[cp_data['cp_type'] == '0', 'cp_type'] = 'Typical Angina'
cp_data.loc[cp_data['cp_type'] == '1', 'cp_type'] = 'Atypical Angina'
cp_data.loc[cp_data['cp_type'] == '2', 'cp_type'] = 'Non-anginal'
cp_data.loc[cp_data['cp_type'] == '3', 'cp_type'] = 'Asymptomatic'

# Done!
print(cp_data)
# Out:
#            cp_type  count
# 0   Typical Angina    143
# 1      Non-anginal     87
# 2  Atypical Angina     50
# 3     Asymptomatic     23

# %%
plt.figure(figsize=(10, 7))
plt.title("Chest Pain of Patients")

sns.barplot(x=cp_data['cp_type'],y= cp_data['count'])
# Out:
# <Axes: title={'center': 'Chest Pain of Patients'}, xlabel='cp_type', ylabel='count'>

# %% [markdown]
# The distribution of chest pain categories is clearly illustrated.

# %%
ecg_data= df['restecg'].value_counts().reset_index()
ecg_data.columns = ['ecg_data', 'count']
ecg_data.loc[ecg_data['ecg_data'] == 0, 'ecg_data'] = 'normal'
ecg_data.loc[ecg_data['ecg_data'] == 1, 'ecg_data'] = 'having ST-T wave abnormality'
ecg_data.loc[ecg_data['ecg_data'] == 2, 'ecg_data'] = 'showing probable or definite left ventricular hypertrophy by Estes'

ecg_data
# Out:
# <ipython-input-55-cc3fcd604395>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'normal' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   ecg_data.loc[ecg_data['ecg_data'] == 0, 'ecg_data'] = 'normal'
#                                             ecg_data  count
# 0                       having ST-T wave abnormality    152
# 1                                             normal    147
# 2  showing probable or definite left ventricular ...      4

# %%
plt.figure(figsize=(10, 7))
plt.title("ECG data of Patients")

sns.barplot(x=ecg_data['ecg_data'], y=ecg_data['count'])
# Out:
# <Axes: title={'center': 'ECG data of Patients'}, xlabel='ecg_data', ylabel='count'>
